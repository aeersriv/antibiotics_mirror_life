# %% [raw]
# ---
# This is metadata:
#
# Kernel: bioinformatics (Python 3.14.0)
# Path:   /var/home/aeersriv/.anaconda3/envs/bioinformatics/bin/python
# ---

# %% [markdown]
# # Retrieve Targets
#
# This notebook retrieves the targets for particular ligand
# class, refer to `targets` (from `src.CONST.targets.Targets`),
# using Biopython `Bio.PDB.PDBList`'s `download_pdb_files` function.

# %% [markdown]
# ## Preliminaries

# %%
from Bio.PDB import PDBList

from src.CONST.targets import Targets

# %% [markdown]
# ## Target Retrieval

# %%
targets = Targets.TARGETS
targets
# Out:
# {'6I1H': ['amoxicillin',
#   'piperacillin',
#   'ticarcillin',
#   'cefepime',
#   'cefazolin',
#   'ceftolozane',
#   'ceftriaxone',
#   'ceftazidime',
#   'aztreonam',
#   'imipenem',
#   'meropenem',
#   'doripenem'],
#  '1FVM': ['vancomycin'],
#  '8CF1': ['minocycline',
#   'tigecycline',
#   'doxycycline',
#   'tetracycline',
#   'chlortetracycline'],
#  '8CGD': ['azithromycin', 'erythromycin', 'clarithromycin', 'chlorampenicol'],
#  '1NJI': ['azithromycin', 'erythromycin', 'clarithromycin', 'chlorampenicol'],
#  '7S1H': ['linezolid'],
#  '1YNN': ['rifampicin'],
#  '1YBG': ['fosfomycin'],
#  '4DUH': ['ciprofloxacin', 'levofloxacin', 'moxifloxacin'],
#  '8C41': ['ciprofloxacin', 'levofloxacin', 'moxifloxacin'],
#  '1FJG': ['amikacin', 'tobramycin', 'streptomycin', 'kanamycin'],
#  '3FL9': ['trimethoprim'],
#  '1TX2': ['sulfamethoxazole'],
#  '3TZF': ['sulfamethoxazole']}

# %%
targets = list(
        targets.keys()
    )
targets
# Out:
# ['6I1H',
#  '1FVM',
#  '8CF1',
#  '8CGD',
#  '1NJI',
#  '7S1H',
#  '1YNN',
#  '1YBG',
#  '4DUH',
#  '8C41',
#  '1FJG',
#  '3FL9',
#  '1TX2',
#  '3TZF']

# %%
PDBList().download_pdb_files(
    pdb_codes=targets,
    file_format="pdb",
    overwrite=True,
    pdir="../data/targets"
)
# Out:
# Downloading PDB structure '6i1h'...
# Downloading PDB structure '1fvm'...
# Downloading PDB structure '8cf1'...
# Downloading PDB structure '8cgd'...
# Downloading PDB structure '1nji'...
# Downloading PDB structure '7s1h'...
# Downloading PDB structure '1ynn'...
# Downloading PDB structure '1ybg'...
# Downloading PDB structure '4duh'...
# Downloading PDB structure '8c41'...
# Downloading PDB structure '1fjg'...
# Downloading PDB structure '3fl9'...
# Downloading PDB structure '1tx2'...
# Downloading PDB structure '3tzf'...
# Desired structure not found or download failed. '7s1h': HTTP Error 404: Not Found
