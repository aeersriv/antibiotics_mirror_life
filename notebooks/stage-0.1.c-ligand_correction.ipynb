# %% [raw]
# ---
# This is metadata:
#
# Kernel: bioinformatics (Python 3.14.0)
# Path:   /var/home/aeersriv/.anaconda3/envs/bioinformatics/bin/python
# ---

# %% [markdown]
# # Ligand Dataset Correction (Stage 0.1.c)
#
# Drop vancomycin in dataset

# %% [markdown]
# ## Preliminaries

# %%
import pandas as pd

# %% [markdown]
# ## Dropping of Vancomycin

# %%
mirr_lig = pd.read_csv("../data/mirror_ligand.csv", index_col=0)
ligands = pd.read_csv("../data/natural_antibiotics.csv", index_col=0)

# %%
mirr_lig.head()
# Out:
#                                                        amoxicillin  \
# cid                                                          33613
# smiles           CC1([C@@H](N2[C@H](S1)[C@@H](C2=O)NC(=O)[C@@H]...
# inchi            InChI=1S/C16H19N3O5S/c1-16(2)11(15(23)24)19-13...
# coordinate_type                                                 2d
# mirror_smi       CC1(C)S[C@H]2[C@@H](NC(=O)[C@@H](N)c3ccc(O)cc3...
#
#                                                       piperacillin  \
# cid                                                          43672
# smiles           CCN1CCN(C(=O)C1=O)C(=O)N[C@H](C2=CC=CC=C2)C(=O...
# inchi            InChI=1S/C23H27N5O7S/c1-4-26-10-11-27(19(32)18...
# coordinate_type                                                 2d
# mirror_smi       CCN1CCN(C(=O)N[C@H](C(=O)N[C@H]2C(=O)N3[C@H]2S...
#
#                                                        ticarcillin  \
# cid                                                          36921
# ...

# %%
ligands.head()
# Out:
#                                                        amoxicillin  \
# cid                                                          33613
# smiles           CC1([C@@H](N2[C@H](S1)[C@@H](C2=O)NC(=O)[C@@H]...
# inchi            InChI=1S/C16H19N3O5S/c1-16(2)11(15(23)24)19-13...
# coordinate_type                                                 2d
# xlogp                                                           -2
#
#                                                       piperacillin  \
# cid                                                          43672
# smiles           CCN1CCN(C(=O)C1=O)C(=O)N[C@H](C2=CC=CC=C2)C(=O...
# inchi            InChI=1S/C23H27N5O7S/c1-4-26-10-11-27(19(32)18...
# coordinate_type                                                 2d
# xlogp                                                          0.5
#
#                                                        ticarcillin  \
# cid                                                          36921
# ...

# %%
ligands = ligands.drop("vancomycin", axis=1)
mirr_lig = mirr_lig.drop("vancomycin", axis=1)

# %%
ligands
# Out:
#                                                              amoxicillin  \
# cid                                                                33613
# smiles                 CC1([C@@H](N2[C@H](S1)[C@@H](C2=O)NC(=O)[C@@H]...
# inchi                  InChI=1S/C16H19N3O5S/c1-16(2)11(15(23)24)19-13...
# coordinate_type                                                       2d
# xlogp                                                                 -2
# tpsa                                                                 158
# h_bond_donor_count                                                     4
# h_bond_acceptor_count                                                  7
# rotatable_bond_count                                                   4
# cactvs_fingerprint     1110000001111011001110000000000001000000000000...
#
#                                                             piperacillin  \
# cid                                                                43672
# ...

# %%
mirr_lig
# Out:
#                                                        amoxicillin  \
# cid                                                          33613
# smiles           CC1([C@@H](N2[C@H](S1)[C@@H](C2=O)NC(=O)[C@@H]...
# inchi            InChI=1S/C16H19N3O5S/c1-16(2)11(15(23)24)19-13...
# coordinate_type                                                 2d
# mirror_smi       CC1(C)S[C@H]2[C@@H](NC(=O)[C@@H](N)c3ccc(O)cc3...
#
#                                                       piperacillin  \
# cid                                                          43672
# smiles           CCN1CCN(C(=O)C1=O)C(=O)N[C@H](C2=CC=CC=C2)C(=O...
# inchi            InChI=1S/C23H27N5O7S/c1-4-26-10-11-27(19(32)18...
# coordinate_type                                                 2d
# mirror_smi       CCN1CCN(C(=O)N[C@H](C(=O)N[C@H]2C(=O)N3[C@H]2S...
#
#                                                        ticarcillin  \
# cid                                                          36921
# ...

# %%
ligands.to_csv("../data/natural_antibiotics.csv")
mirr_lig.to_csv("../data/mirror_ligand.csv")
