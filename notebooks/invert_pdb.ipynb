# %% [raw]
# Antibiotics Mirror Life
# ÆĒR ŚRĪV (c) 2025
# GNU General Public License v3 (GPLv3)

# %% [markdown]
# # Antibiotics Mirror Life
#
# This notebook inverts the given L-chiral of amino acids in
# the given target receptor (or any structure of suitable format)
# and subsequently verify produced enantiomeric form.

# %%
from src.utils.invert_pdb import invert_pdb_coordinates
from src.utils.verify_inversion import verify
