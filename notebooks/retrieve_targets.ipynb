# %% [markdown]
# # Retrieve Targets
#
# This notebook retrieves the targets for particular ligand
# class, refer to `ligand_targets`., using Biopython
# `Bio.PDB.PDBList`'s `download_pdb_files` function.

# %% [markdown]
# ## Preliminaries

# %%
from Bio.PDB import PDBList

# %% [markdown]
# ## Target Retrieval

# %%
ligand_targets: dict[str, list[str]] = {
        "6I1H": [
            "amoxicillin", # penicillins
            "piperacillin",
            "ticarcillin",
            "cefepime", # cephalosporins
            "cefazolin",
            "ceftolozane",
            "ceftriaxone",
            "ceftazidime",
            "aztreonam", # monobactam
            "imipenem", # carbapenems
            "meropenem",
            "doripenem"
        ],
        "5M18": [
            "amoxicillin", # penicillins
            "piperacillin",
            "ticarcillin",
            "cefepime", # cephalosporins
            "cefazolin",
            "ceftolozane",
            "ceftriaxone",
            "ceftazidime",
            "aztreonam", # monobactam
            "imipenem", # carbapenems
            "meropenem",
            "doripenem"
        ],
        "1FVM": [
            "vancomycin" # glycopeptide
        ],
        "8CF1": [ # 30S subunit
            "minocycline", # tetracyclines
            "tigecycline",
            "doxycycline",
            "tetracycline",
            "Chlortetracycline",
            "amikacin", # aminoglycosides
            "tobramycin",
            "streptomycin",
            "kanamycin"
        ],
        "8CGD": [ # 50S subunit
            "azithromycin", # macrolides
            "erythromycin",
            "clarithromycin",
            "chloramphenicol" # chlorampenicol
        ],
        "3FL9": [
            "trimethoprim" # trimethoprim
        ],
        "1TX2": [
            "sulfamethoxazole" # sulfamethoxazole
        ],
        "4DUH": [
            "ciprofloxacin", # quinolones
            "levofloxacin",
            "Moxifloxacin"
        ]
    }

# %%
targets = list(ligand_targets.keys())

# %%
PDBList().download_pdb_files(
    pdb_codes=targets,
    file_format="pdb",
    overwrite=True,
    pdir="../data/target"
)
